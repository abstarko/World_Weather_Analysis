# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs =zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        

            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cockburn town
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | nkhotakota
# Processing Record 4 of Set 1 | luena
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | birao
# Processing Record 7 of Set 1 | ribeira brava
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | san lorenzo
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | mana
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 1 | rudnichnyy
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | interlaken
# Processing Record 19 of Set 1 | bubaque
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | farafangana
# Processing Record 22 of Set 1 | nouadhibou
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | meulaboh
# Processing Record 25 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 1 | oranjemund
# Processing Record 29 of Set 1 | bridgeton
# Processing Record 30 of Set 1 | andenes
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | sao paulo de olivenca
# Processing Record 35 of Set 1 | narsaq
# Processing Record 36 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 1 | punto fijo
# Processing Record 38 of Set 1 | faya
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | san carlos de bariloche
# Processing Record 41 of Set 1 | ullal
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | matamba
# Processing Record 45 of Set 1 | kangaatsiaq
# Processing Record 46 of Set 1 | gidole
# Processing Record 47 of Set 1 | roald
# Processing Record 48 of Set 1 | camana
# Processing Record 49 of Set 1 | san cristobal
# Processing Record 50 of Set 1 | huarmey
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | kaduna
# Processing Record 3 of Set 2 | bethanien
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | olafsvik
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | maxixe
# Processing Record 8 of Set 2 | jhudo
# Processing Record 9 of Set 2 | olinda
# Processing Record 10 of Set 2 | bataipora
# Processing Record 11 of Set 2 | hearst
# Processing Record 12 of Set 2 | klaksvik
# Processing Record 13 of Set 2 | salalah
# Processing Record 14 of Set 2 | humberto de campos
# Processing Record 15 of Set 2 | buchanan
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | hobyo
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | nuuk
# Processing Record 20 of Set 2 | viru
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | sur
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | iralaya
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | montepuez
# Processing Record 29 of Set 2 | ballina
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | harper
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | xai-xai
# Processing Record 34 of Set 2 | bengkulu
# Processing Record 35 of Set 2 | fort-shevchenko
# Processing Record 36 of Set 2 | praia da vitoria
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | boende
# Processing Record 40 of Set 2 | gairo
# Processing Record 41 of Set 2 | caluquembe
# Processing Record 42 of Set 2 | anamur
# Processing Record 43 of Set 2 | vani
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | usevya
# Processing Record 46 of Set 2 | akhtanizovskaya
# Processing Record 47 of Set 2 | coihaique
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | villa bruzual
# Processing Record 50 of Set 2 | antofagasta
# Processing Record 1 of Set 3 | skjaerhollen
# City not found. Skipping...
# Processing Record 2 of Set 3 | tall kayf
# Processing Record 3 of Set 3 | mahajanga
# Processing Record 4 of Set 3 | conde
# Processing Record 5 of Set 3 | stephenville crossing
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | sabha
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | mehran
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | surgut
# Processing Record 13 of Set 3 | marsh harbour
# Processing Record 14 of Set 3 | amurrio
# Processing Record 15 of Set 3 | wum
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | puerto montt
# Processing Record 18 of Set 3 | touros
# Processing Record 19 of Set 3 | bambous virieux
# Processing Record 20 of Set 3 | tarpon springs
# Processing Record 21 of Set 3 | pastavy
# Processing Record 22 of Set 3 | marmarion
# Processing Record 23 of Set 3 | san pedro de macoris
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | rio grande
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | poli
# Processing Record 28 of Set 3 | saint-pierre
# Processing Record 29 of Set 3 | mbanza-ngungu
# Processing Record 30 of Set 3 | mitsamiouli
# Processing Record 31 of Set 3 | tessalit
# Processing Record 32 of Set 3 | los llanos de aridane
# Processing Record 33 of Set 3 | kuvshinovo
# Processing Record 34 of Set 3 | muros
# Processing Record 35 of Set 3 | aguada de pasajeros
# Processing Record 36 of Set 3 | sault sainte marie
# Processing Record 37 of Set 3 | morant bay
# Processing Record 38 of Set 3 | berlevag
# Processing Record 39 of Set 3 | bridlington
# Processing Record 40 of Set 3 | derbent
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | westport
# Processing Record 44 of Set 3 | lesu
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | camacha
# Processing Record 48 of Set 3 | general elizardo aquino
# Processing Record 49 of Set 3 | pangnirtung
# Processing Record 50 of Set 3 | chanteloup-les-vignes
# Processing Record 1 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 2 of Set 4 | crixas
# Processing Record 3 of Set 4 | valjala
# City not found. Skipping...
# Processing Record 4 of Set 4 | rio claro
# Processing Record 5 of Set 4 | presidencia roque saenz pena
# Processing Record 6 of Set 4 | luanda
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | medea
# Processing Record 9 of Set 4 | villazon
# Processing Record 10 of Set 4 | port-gentil
# Processing Record 11 of Set 4 | pitimbu
# Processing Record 12 of Set 4 | naantali
# Processing Record 13 of Set 4 | nyrob
# Processing Record 14 of Set 4 | asfi
# Processing Record 15 of Set 4 | petrolina de goias
# Processing Record 16 of Set 4 | praia
# Processing Record 17 of Set 4 | kavaratti
# Processing Record 18 of Set 4 | morondava
# Processing Record 19 of Set 4 | ostrovnoy
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | nicoya
# Processing Record 22 of Set 4 | namibe
# Processing Record 23 of Set 4 | aquiraz
# Processing Record 24 of Set 4 | grand gaube
# Processing Record 25 of Set 4 | puerto ayora
# Processing Record 26 of Set 4 | taltal
# Processing Record 27 of Set 4 | alta floresta
# Processing Record 28 of Set 4 | novyy urengoy
# Processing Record 29 of Set 4 | geraldton
# Processing Record 30 of Set 4 | moshupa
# Processing Record 31 of Set 4 | bafra
# Processing Record 32 of Set 4 | matara
# Processing Record 33 of Set 4 | santa rosa
# Processing Record 34 of Set 4 | kerchevskiy
# Processing Record 35 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | totness
# Processing Record 37 of Set 4 | walvis bay
# Processing Record 38 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 4 | maniitsoq
# Processing Record 40 of Set 4 | isabela
# Processing Record 41 of Set 4 | melilla
# Processing Record 42 of Set 4 | wagar
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | arraial do cabo
# Processing Record 45 of Set 4 | adrar
# Processing Record 46 of Set 4 | lugovskoy
# Processing Record 47 of Set 4 | shelburne
# Processing Record 48 of Set 4 | burgeo
# Processing Record 49 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 4 | porto novo
# Processing Record 1 of Set 5 | mehamn
# Processing Record 2 of Set 5 | petukhovo
# Processing Record 3 of Set 5 | gardanne
# Processing Record 4 of Set 5 | zaranj
# Processing Record 5 of Set 5 | vestmannaeyjar
# Processing Record 6 of Set 5 | butterworth
# Processing Record 7 of Set 5 | lagoa formosa
# Processing Record 8 of Set 5 | leno
# Processing Record 9 of Set 5 | puerto ayacucho
# Processing Record 10 of Set 5 | mao
# Processing Record 11 of Set 5 | formosa
# Processing Record 12 of Set 5 | havelock
# Processing Record 13 of Set 5 | batticaloa
# Processing Record 14 of Set 5 | marawi
# Processing Record 15 of Set 5 | ponta delgada
# Processing Record 16 of Set 5 | caravelas
# Processing Record 17 of Set 5 | hambantota
# Processing Record 18 of Set 5 | moose factory
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | sambava
# Processing Record 21 of Set 5 | santiago del estero
# Processing Record 22 of Set 5 | cerrito
# Processing Record 23 of Set 5 | changji
# Processing Record 24 of Set 5 | beloha
# Processing Record 25 of Set 5 | mezen
# Processing Record 26 of Set 5 | skibbereen
# Processing Record 27 of Set 5 | serik
# Processing Record 28 of Set 5 | mamlyutka
# Processing Record 29 of Set 5 | pavda
# City not found. Skipping...
# Processing Record 30 of Set 5 | siilinjarvi
# Processing Record 31 of Set 5 | itarema
# Processing Record 32 of Set 5 | krotoszyn
# Processing Record 33 of Set 5 | bonavista
# Processing Record 34 of Set 5 | cayenne
# Processing Record 35 of Set 5 | zhanaozen
# Processing Record 36 of Set 5 | axim
# Processing Record 37 of Set 5 | santa ana
# Processing Record 38 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 5 | nueve de julio
# Processing Record 40 of Set 5 | toledo
# Processing Record 41 of Set 5 | husavik
# Processing Record 42 of Set 5 | taman
# Processing Record 43 of Set 5 | machali
# Processing Record 44 of Set 5 | floro
# Processing Record 45 of Set 5 | calama
# Processing Record 46 of Set 5 | sept-iles
# Processing Record 47 of Set 5 | connersville
# Processing Record 48 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 50 of Set 5 | sawakin
# Processing Record 1 of Set 6 | buraydah
# Processing Record 2 of Set 6 | am timan
# Processing Record 3 of Set 6 | sergeyevka
# Processing Record 4 of Set 6 | oskemen
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | maldonado
# Processing Record 7 of Set 6 | san rafael
# Processing Record 8 of Set 6 | dolores
# Processing Record 9 of Set 6 | damghan
# Processing Record 10 of Set 6 | birjand
# Processing Record 11 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 6 | havoysund
# Processing Record 13 of Set 6 | teguise
# Processing Record 14 of Set 6 | leshukonskoye
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | tandil
# Processing Record 17 of Set 6 | teguldet
# Processing Record 18 of Set 6 | verkhoturye
# Processing Record 19 of Set 6 | ardesen
# Processing Record 20 of Set 6 | talnakh
# Processing Record 21 of Set 6 | jutai
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | plouzane
# Processing Record 24 of Set 6 | filingue
# Processing Record 25 of Set 6 | campos
# Processing Record 26 of Set 6 | sao jose da coroa grande
# Processing Record 27 of Set 6 | esil
# Processing Record 28 of Set 6 | karabuk
# Processing Record 29 of Set 6 | likasi
# Processing Record 30 of Set 6 | lebu
# Processing Record 31 of Set 6 | rio brilhante
# Processing Record 32 of Set 6 | sechura
# Processing Record 33 of Set 6 | lusambo
# Processing Record 34 of Set 6 | saint-georges
# Processing Record 35 of Set 6 | pointe michel
# Processing Record 36 of Set 6 | lima
# Processing Record 37 of Set 6 | zilair
# Processing Record 38 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 39 of Set 6 | atar
# Processing Record 40 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 6 | sabya
# Processing Record 42 of Set 6 | ivangorod
# Processing Record 43 of Set 6 | polunochnoye
# Processing Record 44 of Set 6 | goderich
# Processing Record 45 of Set 6 | parrita
# Processing Record 46 of Set 6 | santa maria
# Processing Record 47 of Set 6 | stromness
# Processing Record 48 of Set 6 | camacari
# Processing Record 49 of Set 6 | vestmanna
# Processing Record 50 of Set 6 | kyzyl-suu
# Processing Record 1 of Set 7 | shubarkuduk
# Processing Record 2 of Set 7 | thompson
# Processing Record 3 of Set 7 | roquetas de mar
# Processing Record 4 of Set 7 | zanjan
# Processing Record 5 of Set 7 | milverton
# Processing Record 6 of Set 7 | awbari
# Processing Record 7 of Set 7 | grindavik
# Processing Record 8 of Set 7 | impfondo
# Processing Record 9 of Set 7 | prizren
# Processing Record 10 of Set 7 | mahibadhoo
# Processing Record 11 of Set 7 | galchino
# City not found. Skipping...
# Processing Record 12 of Set 7 | bar-le-duc
# Processing Record 13 of Set 7 | acari
# Processing Record 14 of Set 7 | vila velha
# Processing Record 15 of Set 7 | bongandanga
# Processing Record 16 of Set 7 | dwarka
# Processing Record 17 of Set 7 | coquimbo
# Processing Record 18 of Set 7 | maraa
# Processing Record 19 of Set 7 | puerto carreno
# Processing Record 20 of Set 7 | mokrous
# Processing Record 21 of Set 7 | chapais
# Processing Record 22 of Set 7 | tolon
# Processing Record 23 of Set 7 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 24 of Set 7 | kushmurun
# Processing Record 25 of Set 7 | ilinskiy
# Processing Record 26 of Set 7 | jaisalmer
# Processing Record 27 of Set 7 | sisimiut
# Processing Record 28 of Set 7 | abeche
# Processing Record 29 of Set 7 | kaoma
# Processing Record 30 of Set 7 | vagamo
# Processing Record 31 of Set 7 | raudeberg
# Processing Record 32 of Set 7 | turukhansk
# Processing Record 33 of Set 7 | jacareacanga
# Processing Record 34 of Set 7 | cabedelo
# Processing Record 35 of Set 7 | castro
# Processing Record 36 of Set 7 | wattegama
# Processing Record 37 of Set 7 | arlit
# Processing Record 38 of Set 7 | tazovskiy
# Processing Record 39 of Set 7 | hamilton
# Processing Record 40 of Set 7 | masunga
# Processing Record 41 of Set 7 | krasnoselkup
# Processing Record 42 of Set 7 | amalapuram
# Processing Record 43 of Set 7 | necochea
# Processing Record 44 of Set 7 | keetmanshoop
# Processing Record 45 of Set 7 | dunkwa
# Processing Record 46 of Set 7 | sao miguel do araguaia
# Processing Record 47 of Set 7 | aragarcas
# Processing Record 48 of Set 7 | bilgoraj
# Processing Record 49 of Set 7 | bermejo
# Processing Record 50 of Set 7 | podgornaya
# Processing Record 1 of Set 8 | hammerfest
# Processing Record 2 of Set 8 | vazante
# Processing Record 3 of Set 8 | soyo
# Processing Record 4 of Set 8 | zafarwal
# Processing Record 5 of Set 8 | gwadar
# Processing Record 6 of Set 8 | yavatmal
# Processing Record 7 of Set 8 | chernyshkovskiy
# Processing Record 8 of Set 8 | menongue
# Processing Record 9 of Set 8 | gitega
# Processing Record 10 of Set 8 | zastron
# Processing Record 11 of Set 8 | natal
# Processing Record 12 of Set 8 | dekar
# Processing Record 13 of Set 8 | rioblanco
# Processing Record 14 of Set 8 | mosquera
# Processing Record 15 of Set 8 | andros town
# Processing Record 16 of Set 8 | misratah
# Processing Record 17 of Set 8 | bilma
# Processing Record 18 of Set 8 | salaverry
# Processing Record 19 of Set 8 | cozieni
# Processing Record 20 of Set 8 | baiao
# Processing Record 21 of Set 8 | septemvri
# Processing Record 22 of Set 8 | aasiaat
# Processing Record 23 of Set 8 | mushie
# Processing Record 24 of Set 8 | korkmaskala
# Processing Record 25 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 26 of Set 8 | maceio
# Processing Record 27 of Set 8 | rasulabad
# Processing Record 28 of Set 8 | mogadishu
# Processing Record 29 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 8 | numan
# Processing Record 31 of Set 8 | la roche-sur-yon
# Processing Record 32 of Set 8 | lunca corbului
# Processing Record 33 of Set 8 | lasa
# Processing Record 34 of Set 8 | podor
# Processing Record 35 of Set 8 | inirida
# Processing Record 36 of Set 8 | ancud
# Processing Record 37 of Set 8 | abalak
# Processing Record 38 of Set 8 | kannangad
# Processing Record 39 of Set 8 | havre-saint-pierre
# Processing Record 40 of Set 8 | dingle
# Processing Record 41 of Set 8 | sudak
# Processing Record 42 of Set 8 | krasnoarmeyskoye
# Processing Record 43 of Set 8 | kama
# Processing Record 44 of Set 8 | dhandhuka
# Processing Record 45 of Set 8 | paracuru
# Processing Record 46 of Set 8 | inderka
# Processing Record 47 of Set 8 | mustasaari
# Processing Record 48 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 8 | rawson
# Processing Record 50 of Set 8 | yashkul
# Processing Record 1 of Set 9 | hamina
# Processing Record 2 of Set 9 | tomter
# Processing Record 3 of Set 9 | srivardhan
# Processing Record 4 of Set 9 | viedma
# Processing Record 5 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 9 | pisco
# Processing Record 7 of Set 9 | boca do acre
# Processing Record 8 of Set 9 | krivosheino
# Processing Record 9 of Set 9 | vila franca do campo
# Processing Record 10 of Set 9 | sorland
# Processing Record 11 of Set 9 | shache
# Processing Record 12 of Set 9 | ongandjera
# Processing Record 13 of Set 9 | cairo
# Processing Record 14 of Set 9 | kankon
# Processing Record 15 of Set 9 | ileza
# Processing Record 16 of Set 9 | the valley
# Processing Record 17 of Set 9 | kedrovyy
# Processing Record 18 of Set 9 | keti bandar
# Processing Record 19 of Set 9 | carnarvon
# Processing Record 20 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 9 | kingsland
# Processing Record 22 of Set 9 | arona
# Processing Record 23 of Set 9 | saa
# Processing Record 24 of Set 9 | umm lajj
# Processing Record 25 of Set 9 | trento
# Processing Record 26 of Set 9 | mugumu
# Processing Record 27 of Set 9 | ust-tsilma
# Processing Record 28 of Set 9 | san andres
# Processing Record 29 of Set 9 | les cayes
# Processing Record 30 of Set 9 | nortelandia
# Processing Record 31 of Set 9 | san joaquin
# Processing Record 32 of Set 9 | san
# Processing Record 33 of Set 9 | jeremoabo
# Processing Record 34 of Set 9 | inverness
# Processing Record 35 of Set 9 | comodoro rivadavia
# Processing Record 36 of Set 9 | jardim
# Processing Record 37 of Set 9 | belokurikha
# Processing Record 38 of Set 9 | stara vyzhivka
# Processing Record 39 of Set 9 | bayshore gardens
# Processing Record 40 of Set 9 | nahrin
# Processing Record 41 of Set 9 | paita
# Processing Record 42 of Set 9 | orthez
# Processing Record 43 of Set 9 | borodino
# Processing Record 44 of Set 9 | theunissen
# Processing Record 45 of Set 9 | tuysarkan
# City not found. Skipping...
# Processing Record 46 of Set 9 | labytnangi
# Processing Record 47 of Set 9 | oistins
# Processing Record 48 of Set 9 | sinnamary
# Processing Record 49 of Set 9 | fethiye
# Processing Record 50 of Set 9 | pasni
# Processing Record 1 of Set 10 | sulechow
# Processing Record 2 of Set 10 | bonthe
# Processing Record 3 of Set 10 | placido de castro
# Processing Record 4 of Set 10 | lichtenburg
# Processing Record 5 of Set 10 | kailaras
# Processing Record 6 of Set 10 | khorixas
# Processing Record 7 of Set 10 | belmonte
# Processing Record 8 of Set 10 | kudahuvadhoo
# Processing Record 9 of Set 10 | tucuma
# Processing Record 10 of Set 10 | colchester
# Processing Record 11 of Set 10 | kindu
# Processing Record 12 of Set 10 | tabou
# Processing Record 13 of Set 10 | bajil
# Processing Record 14 of Set 10 | trofors
# Processing Record 15 of Set 10 | saint anthony
# Processing Record 16 of Set 10 | corciano
# Processing Record 17 of Set 10 | nouakchott
# Processing Record 18 of Set 10 | torello
# Processing Record 19 of Set 10 | wajir
# Processing Record 20 of Set 10 | murgab
# Processing Record 21 of Set 10 | synya
# Processing Record 22 of Set 10 | barra do bugres
# Processing Record 23 of Set 10 | rakke
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | monte patria
# Processing Record 26 of Set 10 | kozhevnikovo
# Processing Record 27 of Set 10 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 28 of Set 10 | reconquista
# Processing Record 29 of Set 10 | sayyan
# Processing Record 30 of Set 10 | osakarovka
# Processing Record 31 of Set 10 | muborak
# Processing Record 32 of Set 10 | quatre cocos
# Processing Record 33 of Set 10 | storforshei
# Processing Record 34 of Set 10 | gazojak
# Processing Record 35 of Set 10 | bar harbor
# Processing Record 36 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 37 of Set 10 | san luis
# Processing Record 38 of Set 10 | faridpur
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | navsari
# Processing Record 41 of Set 10 | chulym
# Processing Record 42 of Set 10 | miraflores
# Processing Record 43 of Set 10 | colares
# Processing Record 44 of Set 10 | manyana
# Processing Record 45 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 10 | gamba
# Processing Record 48 of Set 10 | valenca do piaui
# Processing Record 49 of Set 10 | derzhavinsk
# Processing Record 50 of Set 10 | perth
# Processing Record 1 of Set 11 | zasheyek
# Processing Record 2 of Set 11 | masallatah
# Processing Record 3 of Set 11 | garm
# City not found. Skipping...
# Processing Record 4 of Set 11 | imbituba
# Processing Record 5 of Set 11 | freeport
# Processing Record 6 of Set 11 | el penon
# Processing Record 7 of Set 11 | la rioja
# Processing Record 8 of Set 11 | doha
# Processing Record 9 of Set 11 | gerash
# Processing Record 10 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 11 | punta alta
# Processing Record 12 of Set 11 | sao sebastiao
# Processing Record 13 of Set 11 | mahon
# Processing Record 14 of Set 11 | shahr-e kord
# Processing Record 15 of Set 11 | louis trichardt
# Processing Record 16 of Set 11 | tahta
# Processing Record 17 of Set 11 | moussoro
# Processing Record 18 of Set 11 | langenzersdorf
# Processing Record 19 of Set 11 | coelho neto
# Processing Record 20 of Set 11 | spas
# Processing Record 21 of Set 11 | barcelona
# Processing Record 22 of Set 11 | abu samrah
# Processing Record 23 of Set 11 | haverfordwest
# Processing Record 24 of Set 11 | pryazha
# Processing Record 25 of Set 11 | tsybli
# Processing Record 26 of Set 11 | puerto del rosario
# Processing Record 27 of Set 11 | rehti
# Processing Record 28 of Set 11 | pitanga
# Processing Record 29 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 11 | zhezkazgan
# Processing Record 31 of Set 11 | puerto concordia
# Processing Record 32 of Set 11 | west bay
# Processing Record 33 of Set 11 | carutapera
# Processing Record 34 of Set 11 | nata
# Processing Record 35 of Set 11 | moisei
# Processing Record 36 of Set 11 | asyut
# Processing Record 37 of Set 11 | kashi
# Processing Record 38 of Set 11 | vejen
# Processing Record 39 of Set 11 | sangueya
# Processing Record 40 of Set 11 | novoleushkovskaya
# Processing Record 41 of Set 11 | alfreton
# Processing Record 42 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 43 of Set 11 | talara
# Processing Record 44 of Set 11 | capinzal
# Processing Record 45 of Set 11 | ciudad bolivar
# Processing Record 46 of Set 11 | la peca
# Processing Record 47 of Set 11 | ivanava
# Processing Record 48 of Set 11 | bashmakovo
# Processing Record 49 of Set 11 | otavi
# Processing Record 50 of Set 11 | beisfjord
# Processing Record 1 of Set 12 | ginda
# Processing Record 2 of Set 12 | rivera
# Processing Record 3 of Set 12 | pocone
# Processing Record 4 of Set 12 | nisia floresta
# Processing Record 5 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 12 | moguer
# Processing Record 7 of Set 12 | samana
# Processing Record 8 of Set 12 | rottingdean
# Processing Record 9 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 10 of Set 12 | manono
# Processing Record 11 of Set 12 | bahia honda
# Processing Record 12 of Set 12 | saint-joseph
# Processing Record 13 of Set 12 | narodychi
# Processing Record 14 of Set 12 | saint-louis
# Processing Record 15 of Set 12 | nalut
# Processing Record 16 of Set 12 | mbekenyera
# Processing Record 17 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 18 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 19 of Set 12 | concepcion
# Processing Record 20 of Set 12 | pemba
# Processing Record 21 of Set 12 | rimouski
# Processing Record 22 of Set 12 | ilek
# Processing Record 23 of Set 12 | puerto quijarro
# Processing Record 24 of Set 12 | hun
# Processing Record 25 of Set 12 | old road
# City not found. Skipping...
# Processing Record 26 of Set 12 | pozo colorado
# Processing Record 27 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 12 | jalingo
# Processing Record 29 of Set 12 | nefteyugansk
# Processing Record 30 of Set 12 | rock sound
# Processing Record 31 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 32 of Set 12 | leticia
# Processing Record 33 of Set 12 | oudtshoorn
# Processing Record 34 of Set 12 | santiago de cuba
# Processing Record 35 of Set 12 | sioux lookout
# Processing Record 36 of Set 12 | warrington
# Processing Record 37 of Set 12 | maputo
# Processing Record 38 of Set 12 | paamiut
# Processing Record 39 of Set 12 | matagami
# Processing Record 40 of Set 12 | uyuni
# Processing Record 41 of Set 12 | opuwo
# Processing Record 42 of Set 12 | bekhtery
# Processing Record 43 of Set 12 | illapel
# Processing Record 44 of Set 12 | salta
# Processing Record 45 of Set 12 | qorveh
# Processing Record 46 of Set 12 | camopi
# Processing Record 47 of Set 12 | mossendjo
# Processing Record 48 of Set 12 | zaozerne
# Processing Record 49 of Set 12 | rabak
# Processing Record 50 of Set 12 | lovozero
# Processing Record 1 of Set 13 | port blair
# Processing Record 2 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 3 of Set 13 | autazes
# Processing Record 4 of Set 13 | antalaha
# Processing Record 5 of Set 13 | carbondale
# Processing Record 6 of Set 13 | umm kaddadah
# Processing Record 7 of Set 13 | palora
# Processing Record 8 of Set 13 | campana
# Processing Record 9 of Set 13 | najran
# Processing Record 10 of Set 13 | aksay
# Processing Record 11 of Set 13 | addis zemen
# City not found. Skipping...
# Processing Record 12 of Set 13 | salinopolis
# Processing Record 13 of Set 13 | pudozh
# Processing Record 14 of Set 13 | atasu
# Processing Record 15 of Set 13 | kautokeino
# Processing Record 16 of Set 13 | yarada
# Processing Record 17 of Set 13 | polyarnyye zori
# Processing Record 18 of Set 13 | kpandae
# Processing Record 19 of Set 13 | richards bay
# Processing Record 20 of Set 13 | carauari
# Processing Record 21 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 22 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 13 | konitsa
# Processing Record 24 of Set 13 | darnah
# Processing Record 25 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 26 of Set 13 | bhadrachalam
# Processing Record 27 of Set 13 | peniche
# Processing Record 28 of Set 13 | mecca
# Processing Record 29 of Set 13 | huambo
# Processing Record 30 of Set 13 | khotynets
# Processing Record 31 of Set 13 | buncrana
# Processing Record 32 of Set 13 | chardara
# Processing Record 33 of Set 13 | ust-kulom
# Processing Record 34 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 13 | albesti
# Processing Record 36 of Set 13 | valparaiso
# Processing Record 37 of Set 13 | naryan-mar
# Processing Record 38 of Set 13 | mindelo
# Processing Record 39 of Set 13 | moutier
# Processing Record 40 of Set 13 | orlovo
# Processing Record 41 of Set 13 | krasnyy luch
# Processing Record 42 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 13 | henties bay
# Processing Record 44 of Set 13 | anloga
# Processing Record 45 of Set 13 | independence
# Processing Record 46 of Set 13 | rudbar
# Processing Record 47 of Set 13 | svetlyy
# Processing Record 48 of Set 13 | santo antonio do ica
# Processing Record 49 of Set 13 | waw
# Processing Record 50 of Set 13 | macusani
# Processing Record 1 of Set 14 | burica
# City not found. Skipping...
# Processing Record 2 of Set 14 | owerri
# Processing Record 3 of Set 14 | yarega
# Processing Record 4 of Set 14 | kalmunai
# Processing Record 5 of Set 14 | shenkursk
# Processing Record 6 of Set 14 | troitsko-pechorsk
# Processing Record 7 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 8 of Set 14 | saint-augustin
# Processing Record 9 of Set 14 | baghdad
# Processing Record 10 of Set 14 | lasalgaon
# Processing Record 11 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 12 of Set 14 | general roca
# Processing Record 13 of Set 14 | abnub
# Processing Record 14 of Set 14 | mercedes
# Processing Record 15 of Set 14 | eyl
# Processing Record 16 of Set 14 | pancas
# Processing Record 17 of Set 14 | road town
# Processing Record 18 of Set 14 | tallahassee
# Processing Record 19 of Set 14 | gao
# Processing Record 20 of Set 14 | brasilia de minas
# Processing Record 21 of Set 14 | guajara
# Processing Record 22 of Set 14 | ilhabela
# Processing Record 23 of Set 14 | eslov
# Processing Record 24 of Set 14 | humaita
# Processing Record 25 of Set 14 | udimskiy
# Processing Record 26 of Set 14 | sapele
# Processing Record 27 of Set 14 | rio gallegos
# Processing Record 28 of Set 14 | rocha
# Processing Record 29 of Set 14 | bandarbeyla
# Processing Record 30 of Set 14 | fez
# Processing Record 31 of Set 14 | dudinka
# Processing Record 32 of Set 14 | isoka
# Processing Record 33 of Set 14 | challapata
# Processing Record 34 of Set 14 | monte alegre de sergipe
# Processing Record 35 of Set 14 | tortoli
# Processing Record 36 of Set 14 | kabompo
# Processing Record 37 of Set 14 | tostamaa
# City not found. Skipping...
# Processing Record 38 of Set 14 | chimoio
# Processing Record 39 of Set 14 | catamarca
# Processing Record 40 of Set 14 | villablino
# Processing Record 41 of Set 14 | tromso
# Processing Record 42 of Set 14 | san juan
# Processing Record 43 of Set 14 | letterkenny
# Processing Record 44 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 14 | lixourion
# Processing Record 46 of Set 14 | remedios
# Processing Record 47 of Set 14 | barra do garcas
# Processing Record 48 of Set 14 | general pico
# Processing Record 49 of Set 14 | abha
# Processing Record 50 of Set 14 | ugoofaaru
# Processing Record 1 of Set 15 | mitu
# Processing Record 2 of Set 15 | isiro
# Processing Record 3 of Set 15 | cap malheureux
# Processing Record 4 of Set 15 | bogorodskoye
# Processing Record 5 of Set 15 | kisangani
# Processing Record 6 of Set 15 | badgam
# City not found. Skipping...
# Processing Record 7 of Set 15 | korla
# Processing Record 8 of Set 15 | karlovac
# Processing Record 9 of Set 15 | port-cartier
# Processing Record 10 of Set 15 | okitipupa
# Processing Record 11 of Set 15 | porto santo
# Processing Record 12 of Set 15 | damietta
# Processing Record 13 of Set 15 | matadi
# Processing Record 14 of Set 15 | almenevo
# City not found. Skipping...
# Processing Record 15 of Set 15 | aqtobe
# Processing Record 16 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 15 | lebanon
# Processing Record 18 of Set 15 | marovoay
# Processing Record 19 of Set 15 | laredo
# Processing Record 20 of Set 15 | listvyanskiy
# Processing Record 21 of Set 15 | biddeford
# Processing Record 22 of Set 15 | teeli
# Processing Record 23 of Set 15 | assomada
# Processing Record 24 of Set 15 | pangoa
# Processing Record 25 of Set 15 | motala
# Processing Record 26 of Set 15 | celendin
# Processing Record 27 of Set 15 | olenino
# Processing Record 28 of Set 15 | junagarh
# Processing Record 29 of Set 15 | merida
# Processing Record 30 of Set 15 | oktyabrskiy
# Processing Record 31 of Set 15 | jucas
# Processing Record 32 of Set 15 | san jorge
# Processing Record 33 of Set 15 | bid
# City not found. Skipping...
# Processing Record 34 of Set 15 | cervo
# Processing Record 35 of Set 15 | skjervoy
# Processing Record 36 of Set 15 | ipixuna
# Processing Record 37 of Set 15 | mani
# Processing Record 38 of Set 15 | oktyabrskoye
# Processing Record 39 of Set 15 | yaremche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Cockburn Town  21.4612  -71.1419     80.56        65          40
# 1     Port Alfred -33.5906   26.8910     71.19        91           6
# 2      Nkhotakota -12.9274   34.2961     73.24        87          99
# 3           Luena -11.7833   19.9167     61.92        93          76
# 4  Ribeira Grande  38.5167  -28.7000     61.77        88          20
# 5           Birao  10.2849   22.7882     81.05        11          65
# 6   Ribeira Brava  32.6500  -17.0667     63.23        49          25
# 7       Hithadhoo  -0.6000   73.0833     81.14        70          69
# 8      Georgetown   5.4112  100.3354     76.95        99          20
# 9         Ushuaia -54.8000  -68.3000     47.86        57          40
#
#    Wind Speed Country Current Description
# 0       17.27      TC    scattered clouds
# 1        5.01      ZA           clear sky
# 2        6.53      MW          light rain
# 3        7.40      AO       broken clouds
# 4       11.99      PT          few clouds
# 5        5.23      CF       broken clouds
# 6        3.94      PT    scattered clouds
# 7       11.14      MV       broken clouds
# 8        2.30      MY          few clouds
# 9       29.93      AR          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new]

# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Cockburn Town      TC  21.4612 -71.1419     80.56        65          40
# 1     Port Alfred      ZA -33.5906  26.8910     71.19        91           6
# 2      Nkhotakota      MW -12.9274  34.2961     73.24        87          99
# 3           Luena      AO -11.7833  19.9167     61.92        93          76
# 4  Ribeira Grande      PT  38.5167 -28.7000     61.77        88          20
#
#    Wind Speed Current Description
# 0       17.27    scattered clouds
# 1        5.01           clear sky
# 2        6.53          light rain
# 3        7.40       broken clouds
# 4       11.99          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
